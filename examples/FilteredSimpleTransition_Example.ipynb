# %%
import sys
sys.path.append('../')
import tabularepimdl as tepi

import pandas as pd

# %%
df = pd.DataFrame({
    "InfState": ["I", "I", "I", "I", 'S', 'S'],
    "Host": ['cattle', 'cattle', 'human', 'human', 'cattle', 'cattle'],
    "N": [3, 4, 50, 60, 70, 80],
    'T': 0
})

# %%
# Create an instance of the filtered transition rule for 'cattle'
filtered_cattle_rule = tepi.FilteredSimpleTransition(column="InfState", from_st="I", to_st="R", rate=0.1, filter_column="Host", filter_value=["cattle", "human"], stochastic=False)

# Apply the filter to get cattle deltas of I -> R
#cattle_deltas = filtered_cattle_rule.get_deltas(df)
#cattle_deltas

# %%
#print(tepi.FilteredSimpleTransition.mro())

# %%
determ_epi_mdl = tepi.EpiModel(init_state = df, rules=[filtered_cattle_rule], stoch_policy = 'rule_based')

# %%
for i in range(4):
    determ_epi_mdl.do_timestep(dt=0.25)

# %%
determ_epi_mdl.full_epi
# Out:
#    InfState    Host           N     T
# 0         I  cattle    3.000000  0.00
# 1         I  cattle    4.000000  0.00
# 2         I   human   50.000000  0.00
# 3         I   human   60.000000  0.00
# 4         S  cattle   70.000000  0.00
# 5         S  cattle   80.000000  0.00
# 6         I  cattle    6.827169  0.25
# 7         I   human  107.284090  0.25
# 8         R  cattle    0.172831  0.25
# 9         R   human    2.715910  0.25
# 10        S  cattle  150.000000  0.25
# 11        I  cattle    6.658606  0.50
# 12        I   human  104.635237  0.50
# 13        R  cattle    0.341394  0.50
# 14        R   human    5.364763  0.50
# 15        S  cattle  150.000000  0.50
# 16        I  cattle    6.494204  0.75
# 17        I   human  102.051783  0.75
# 18        R  cattle    0.505796  0.75
# 19        R   human    7.948217  0.75
# 20        S  cattle  150.000000  0.75
# 21        I  cattle    6.333862  1.00
# 22        I   human   99.532116  1.00
# 23        R  cattle    0.666138  1.00
# ...

# %%
determ_epi_mdl.cur_state
# Out:
#   InfState    Host           N    T
# 0        I  cattle    6.333862  1.0
# 1        I   human   99.532116  1.0
# 2        R  cattle    0.666138  1.0
# 3        R   human   10.467884  1.0
# 4        S  cattle  150.000000  1.0
