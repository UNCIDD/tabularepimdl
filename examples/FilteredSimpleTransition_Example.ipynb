# %%
import sys
sys.path.append('../')
import tabularepimdl as tepi

import pandas as pd

# %%
df = pd.DataFrame({
    "InfState": ["I", "I", "I", "I", 'S', 'S'],
    "Host": ['cattle', 'cattle', 'human', 'human', 'cattle', 'cattle'],
    "N": [3, 4, 50, 60, 70, 80]
})

# %%
# Create an instance of the filtered transition rule for 'cattle'
filtered_cattle_rule = tepi.FilteredSimpleTransition(column="InfState", from_st="I", to_st="R", rate=0.1, filter_column="Host", filter_value=["cattle", "human"], stochastic=True)

# Apply the filter to get cattle deltas of I -> R
#cattle_deltas = filtered_cattle_rule.filter_get_deltas(df)
#cattle_deltas

# %%
determ_epi_mdl = tepi.EpiModel(init_state = df ,rules=[filtered_cattle_rule], stoch_policy = 'rule_based')

# %%
for i in range(4):
    determ_epi_mdl.do_timestep(dt=0.25)

# %%
determ_epi_mdl.full_epi
# Out:
#    InfState    Host    N     T
# 0         I  cattle    3  0.00
# 1         I  cattle    4  0.00
# 2         I   human   50  0.00
# 3         I   human   60  0.00
# 4         S  cattle   70  0.00
# 5         S  cattle   80  0.00
# 6         I  cattle    7  0.25
# 7         I   human  110  0.25
# 8         S  cattle  150  0.25
# 9         I  cattle    7  0.50
# 10        I   human  107  0.50
# 11        R   human    3  0.50
# 12        S  cattle  150  0.50
# 13        I  cattle    7  0.75
# 14        I   human  104  0.75
# 15        R   human    6  0.75
# 16        S  cattle  150  0.75
# 17        I  cattle    7  1.00
# 18        I   human  104  1.00
# 19        R   human    6  1.00
# 20        S  cattle  150  1.00

# %%
determ_epi_mdl.cur_state
# Out:
#   InfState    Host    N    T
# 0        I  cattle    7  1.0
# 1        I   human  104  1.0
# 2        R   human    6  1.0
# 3        S  cattle  150  1.0
