# %%
import pandas as pd
import numpy as np
from tabularepimdl.SimpleInfection import SimpleInfection
from tabularepimdl.EpiModel import EpiModel

# %%
class Runner():
    """Class to automate running multiple iterations of an EpiModel simulation."""
    
    def __init__(self, model: EpiModel, time_start: int | float = 0, time_end: int | float = 0, time_step: int | float = 0, 
                 reset_flag: bool = False, added_data: pd.DataFrame = None, added_time: list[int | float] = None) -> None:
        """
        Initialization.

        Parameters:
        @para model (EpiModel): The epidemiological model to run simulations on.
        @para time_start: the start time of model simulation.
        @para time_end: the end time of model simulation.
        @para time_step: the incremenal size of time stamp.
        @para reset_flag: Whether to reset the model before running.
        @para added_data: new data points to be added to the model's current state.
        @para added_time: the time point when the new data is added.
        """
        self.model = model
        self.time_start = time_start
        self.time_end = time_end
        self.time_step = time_step
        self.reset_flag = reset_flag
        self.added_data = added_data
        self.added_time = added_time

    def reset_model(self) -> None:
        """Resets the model if the reset_flag is True."""
        if self.reset_flag:
            self.model.reset()
        else:
            pass

    def add_new_data(self, added_time: int | float = 0) -> None:
        """Adds new data to the current state."""
        required_columns = {"T"} #added_data needs to have column T
        #print("going into add_new_data method.")
        
        if not required_columns.issubset(self.model.cur_state.columns): #raise error when adding data at t=0
            raise ValueError ("The initial epi data missed column T.")
        
        #if required_columns.issubset(self.model.cur_state.columns): print('there is T')
        #else: print('no T')
        if self.added_data is not None:
            if required_columns.issubset(self.added_data.columns) and added_time in self.added_data["T"].values: #check if the event time is present in added_data column T
                self.model.cur_state = pd.concat([ self.model.cur_state, self.added_data.loc[self.added_data["T"]==added_time] ], ignore_index=True)
                #print('add new data, cur_state is\n', self.model.cur_state)
            else: raise ValueError (f"The added data does not include record for time {added_time}. Please check the added data.")
        else:
            raise ValueError (f"The added data is None. Please check the added data.")

    def run(self) -> pd.DataFrame:
        """
        Runs the simulation over the specified time range.
        Returns: cur_state at the end of the simulation.
        """
        for t in np.arange(self.time_start, self.time_end, self.time_step):
            if self.added_time is not None and t in self.added_time:
                self.add_new_data(added_time=t) # Inject data if needed at this timestep
            
            self.model.do_timestep(dt=self.time_step)  # Run one timestep

        return self.model.cur_state #only return current state of the Epi model

# %%
population = pd.DataFrame({
    'InfState' : pd.Categorical(['S','I'], categories=['S','I','R']),
    'N' : [999, 1],
    'T': 0.0 #assign T with float number
})

# %%
t=[0.5, 1.0] #added_time
to_add = pd.DataFrame({
    'InfState' : pd.Categorical(['I', 'I'], categories=['S','I','R']),
    'N' : [1, 2],
    'T': [0.5, 1.0]
}) #added_data

# %%
infect_rule = SimpleInfection(beta=0.5, column='InfState')
determ_epi_mdl = EpiModel(init_state = population ,rules=[infect_rule])

# %%
r = Runner(determ_epi_mdl, time_start = 0, time_end=5, time_step=0.25, reset_flag=True, added_data=to_add, added_time=t)
r.reset_model()

# %%
r.run()
# Out:
# initial current_state of each dt is
#    InfState    N    T
# 0        S  999  0.0
# 1        I    1  0.0
# Epi model starts!!!
# current ruleset is
#  [SimpleInfection(stochastic=False, beta=0.5, column='InfState', s_st='S', i_st='I', inf_to='I', freq_dep=True)]
# current rule is
#  stochastic=False beta=0.5 column='InfState' s_st='S' i_st='I' inf_to='I' freq_dep=True
# epi model rule based
# nw_delta is
#    InfState         N    T
# 0        S -0.124867  0.0
# 1        I  0.124867  0.0
# all_deltas is
#    InfState         N    T
# 0        S -0.124867  0.0
# 1        I  0.124867  0.0
# finished current ruleset, moving on
# before concat cur_state and all_deltas, cur_state is
#    InfState    N    T
# 0        S  999  0.0
# 1        I    1  0.0
# before concat cur_state and all_deltas, all_deltas is
#    InfState         N    T
# 0        S -0.124867  0.0
# 1        I  0.124867  0.0
# after concat but before grouping nw_state is
#    InfState           N    T
# 0        S  999.000000  0.0
# 1        I    1.000000  0.0
# 0        S   -0.124867  0.0
# 1        I    0.124867  0.0
# group cols are:  ['InfState']
# ***
# after grouping new state is
#    InfState           N    T
# 0        I    1.124867  0.0
# 1        S  998.875133  0.0
# before adding dt, current_state is
#    InfState           N    T
# 0        I    1.124867  0.0
# 1        S  998.875133  0.0
# for loop ends
# final current_state is
#    InfState           N     T
# 0        I    1.124867  0.25
# 1        S  998.875133  0.25
# full epi is
#    InfState           N     T
# 0        S  999.000000  0.00
# 1        I    1.000000  0.00
# 2        I    1.124867  0.25
# 3        S  998.875133  0.25
# ----
# initial current_state of each dt is
#    InfState           N     T
# 0        I    1.124867  0.25
# 1        S  998.875133  0.25
# Epi model starts!!!
# current ruleset is
#  [SimpleInfection(stochastic=False, beta=0.5, column='InfState', s_st='S', i_st='I', inf_to='I', freq_dep=True)]
# current rule is
#  stochastic=False beta=0.5 column='InfState' s_st='S' i_st='I' inf_to='I' freq_dep=True
# epi model rule based
# nw_delta is
#    InfState        N     T
# 0        S -0.14044  0.25
# 1        I  0.14044  0.25
# all_deltas is
#    InfState        N     T
# 0        S -0.14044  0.25
# 1        I  0.14044  0.25
# finished current ruleset, moving on
# before concat cur_state and all_deltas, cur_state is
#    InfState           N     T
# 0        I    1.124867  0.25
# 1        S  998.875133  0.25
# before concat cur_state and all_deltas, all_deltas is
#    InfState        N     T
# 0        S -0.14044  0.25
# 1        I  0.14044  0.25
# after concat but before grouping nw_state is
#    InfState           N     T
# 0        I    1.124867  0.25
# 1        S  998.875133  0.25
# 0        S   -0.140440  0.25
# 1        I    0.140440  0.25
# group cols are:  ['InfState']
# ***
# after grouping new state is
#    InfState           N     T
# 0        I    1.265308  0.25
# 1        S  998.734692  0.25
# before adding dt, current_state is
#    InfState           N     T
# 0        I    1.265308  0.25
# 1        S  998.734692  0.25
# for loop ends
# final current_state is
#    InfState           N    T
# 0        I    1.265308  0.5
# 1        S  998.734692  0.5
# full epi is
#    InfState           N     T
# 0        S  999.000000  0.00
# 1        I    1.000000  0.00
# 2        I    1.124867  0.25
# 3        S  998.875133  0.25
# 4        I    1.265308  0.50
# 5        S  998.734692  0.50
# ----
# initial current_state of each dt is
#    InfState           N    T
# 0        I    1.265308  0.5
# 1        S  998.734692  0.5
# 2        I    1.000000  0.5
# Epi model starts!!!
# current ruleset is
#  [SimpleInfection(stochastic=False, beta=0.5, column='InfState', s_st='S', i_st='I', inf_to='I', freq_dep=True)]
# current rule is
#  stochastic=False beta=0.5 column='InfState' s_st='S' i_st='I' inf_to='I' freq_dep=True
# epi model rule based
# nw_delta is
#    InfState         N    T
# 0        S -0.282483  0.5
# 1        I  0.282483  0.5
# all_deltas is
#    InfState         N    T
# 0        S -0.282483  0.5
# 1        I  0.282483  0.5
# finished current ruleset, moving on
# before concat cur_state and all_deltas, cur_state is
#    InfState           N    T
# 0        I    1.265308  0.5
# 1        S  998.734692  0.5
# 2        I    1.000000  0.5
# before concat cur_state and all_deltas, all_deltas is
#    InfState         N    T
# 0        S -0.282483  0.5
# 1        I  0.282483  0.5
# after concat but before grouping nw_state is
#    InfState           N    T
# 0        I    1.265308  0.5
# 1        S  998.734692  0.5
# 2        I    1.000000  0.5
# 0        S   -0.282483  0.5
# 1        I    0.282483  0.5
# group cols are:  ['InfState']
# ***
# after grouping new state is
#    InfState          N    T
# 0        I    2.54779  0.5
# 1        S  998.45221  0.5
# before adding dt, current_state is
#    InfState          N    T
# 0        I    2.54779  0.5
# 1        S  998.45221  0.5
# for loop ends
# final current_state is
#    InfState          N     T
# 0        I    2.54779  0.75
# 1        S  998.45221  0.75
# full epi is
#    InfState           N     T
# 0        S  999.000000  0.00
# 1        I    1.000000  0.00
# 2        I    1.124867  0.25
# 3        S  998.875133  0.25
# 4        I    1.265308  0.50
# 5        S  998.734692  0.50
# 6        I    2.547790  0.75
# 7        S  998.452210  0.75
# ----
# initial current_state of each dt is
#    InfState          N     T
# 0        I    2.54779  0.75
# 1        S  998.45221  0.75
# Epi model starts!!!
# current ruleset is
#  [SimpleInfection(stochastic=False, beta=0.5, column='InfState', s_st='S', i_st='I', inf_to='I', freq_dep=True)]
# current rule is
#  stochastic=False beta=0.5 column='InfState' s_st='S' i_st='I' inf_to='I' freq_dep=True
# epi model rule based
# nw_delta is
#    InfState         N     T
# 0        S -0.317613  0.75
# 1        I  0.317613  0.75
# all_deltas is
#    InfState         N     T
# 0        S -0.317613  0.75
# 1        I  0.317613  0.75
# finished current ruleset, moving on
# before concat cur_state and all_deltas, cur_state is
#    InfState          N     T
# 0        I    2.54779  0.75
# 1        S  998.45221  0.75
# before concat cur_state and all_deltas, all_deltas is
#    InfState         N     T
# 0        S -0.317613  0.75
# 1        I  0.317613  0.75
# after concat but before grouping nw_state is
#    InfState           N     T
# 0        I    2.547790  0.75
# 1        S  998.452210  0.75
# 0        S   -0.317613  0.75
# 1        I    0.317613  0.75
# group cols are:  ['InfState']
# ***
# after grouping new state is
#    InfState           N     T
# 0        I    2.865403  0.75
# 1        S  998.134597  0.75
# before adding dt, current_state is
#    InfState           N     T
# 0        I    2.865403  0.75
# 1        S  998.134597  0.75
# for loop ends
# final current_state is
#    InfState           N    T
# 0        I    2.865403  1.0
# 1        S  998.134597  1.0
# full epi is
#    InfState           N     T
# 0        S  999.000000  0.00
# 1        I    1.000000  0.00
# 2        I    1.124867  0.25
# 3        S  998.875133  0.25
# 4        I    1.265308  0.50
# 5        S  998.734692  0.50
# 6        I    2.547790  0.75
# 7        S  998.452210  0.75
# 8        I    2.865403  1.00
# 9        S  998.134597  1.00
# ----
# initial current_state of each dt is
#    InfState           N    T
# 0        I    2.865403  1.0
# 1        S  998.134597  1.0
# 2        I    2.000000  1.0
# Epi model starts!!!
# current ruleset is
#  [SimpleInfection(stochastic=False, beta=0.5, column='InfState', s_st='S', i_st='I', inf_to='I', freq_dep=True)]
# current rule is
#  stochastic=False beta=0.5 column='InfState' s_st='S' i_st='I' inf_to='I' freq_dep=True
# epi model rule based
# nw_delta is
#    InfState         N    T
# 0        S -0.605042  1.0
# 1        I  0.605042  1.0
# all_deltas is
#    InfState         N    T
# 0        S -0.605042  1.0
# 1        I  0.605042  1.0
# finished current ruleset, moving on
# before concat cur_state and all_deltas, cur_state is
#    InfState           N    T
# 0        I    2.865403  1.0
# 1        S  998.134597  1.0
# 2        I    2.000000  1.0
# before concat cur_state and all_deltas, all_deltas is
#    InfState         N    T
# 0        S -0.605042  1.0
# 1        I  0.605042  1.0
# after concat but before grouping nw_state is
#    InfState           N    T
# 0        I    2.865403  1.0
# 1        S  998.134597  1.0
# 2        I    2.000000  1.0
# 0        S   -0.605042  1.0
# 1        I    0.605042  1.0
# group cols are:  ['InfState']
# ***
# after grouping new state is
#    InfState           N    T
# 0        I    5.470445  1.0
# 1        S  997.529555  1.0
# before adding dt, current_state is
#    InfState           N    T
# 0        I    5.470445  1.0
# 1        S  997.529555  1.0
# for loop ends
# final current_state is
#    InfState           N     T
# 0        I    5.470445  1.25
# 1        S  997.529555  1.25
# full epi is
#     InfState           N     T
# 0         S  999.000000  0.00
# 1         I    1.000000  0.00
# 2         I    1.124867  0.25
# 3         S  998.875133  0.25
# 4         I    1.265308  0.50
# 5         S  998.734692  0.50
# 6         I    2.547790  0.75
# 7         S  998.452210  0.75
# 8         I    2.865403  1.00
# 9         S  998.134597  1.00
# 10        I    5.470445  1.25
# 11        S  997.529555  1.25
# ----
# initial current_state of each dt is
#    InfState           N     T
# 0        I    5.470445  1.25
# 1        S  997.529555  1.25
# Epi model starts!!!
# current ruleset is
#  [SimpleInfection(stochastic=False, beta=0.5, column='InfState', s_st='S', i_st='I', inf_to='I', freq_dep=True)]
# current rule is
#  stochastic=False beta=0.5 column='InfState' s_st='S' i_st='I' inf_to='I' freq_dep=True
# epi model rule based
# nw_delta is
#    InfState         N     T
# 0        S -0.679844  1.25
# 1        I  0.679844  1.25
# all_deltas is
#    InfState         N     T
# 0        S -0.679844  1.25
# 1        I  0.679844  1.25
# finished current ruleset, moving on
# before concat cur_state and all_deltas, cur_state is
#    InfState           N     T
# 0        I    5.470445  1.25
# 1        S  997.529555  1.25
# before concat cur_state and all_deltas, all_deltas is
#    InfState         N     T
# 0        S -0.679844  1.25
# 1        I  0.679844  1.25
# after concat but before grouping nw_state is
#    InfState           N     T
# 0        I    5.470445  1.25
# 1        S  997.529555  1.25
# 0        S   -0.679844  1.25
# 1        I    0.679844  1.25
# group cols are:  ['InfState']
# ***
# after grouping new state is
#    InfState           N     T
# 0        I    6.150289  1.25
# 1        S  996.849711  1.25
# before adding dt, current_state is
#    InfState           N     T
# 0        I    6.150289  1.25
# 1        S  996.849711  1.25
# for loop ends
# final current_state is
#    InfState           N    T
# 0        I    6.150289  1.5
# 1        S  996.849711  1.5
# full epi is
#     InfState           N     T
# 0         S  999.000000  0.00
# 1         I    1.000000  0.00
# 2         I    1.124867  0.25
# 3         S  998.875133  0.25
# 4         I    1.265308  0.50
# 5         S  998.734692  0.50
# 6         I    2.547790  0.75
# 7         S  998.452210  0.75
# 8         I    2.865403  1.00
# 9         S  998.134597  1.00
# 10        I    5.470445  1.25
# 11        S  997.529555  1.25
# 12        I    6.150289  1.50
# 13        S  996.849711  1.50
# ----
# initial current_state of each dt is
#    InfState           N    T
# 0        I    6.150289  1.5
# 1        S  996.849711  1.5
# Epi model starts!!!
# current ruleset is
#  [SimpleInfection(stochastic=False, beta=0.5, column='InfState', s_st='S', i_st='I', inf_to='I', freq_dep=True)]
# current rule is
#  stochastic=False beta=0.5 column='InfState' s_st='S' i_st='I' inf_to='I' freq_dep=True
# epi model rule based
# nw_delta is
#    InfState         N    T
# 0        S -0.763779  1.5
# 1        I  0.763779  1.5
# all_deltas is
#    InfState         N    T
# 0        S -0.763779  1.5
# 1        I  0.763779  1.5
# finished current ruleset, moving on
# before concat cur_state and all_deltas, cur_state is
#    InfState           N    T
# 0        I    6.150289  1.5
# 1        S  996.849711  1.5
# before concat cur_state and all_deltas, all_deltas is
#    InfState         N    T
# 0        S -0.763779  1.5
# 1        I  0.763779  1.5
# after concat but before grouping nw_state is
#    InfState           N    T
# 0        I    6.150289  1.5
# 1        S  996.849711  1.5
# 0        S   -0.763779  1.5
# 1        I    0.763779  1.5
# group cols are:  ['InfState']
# ***
# after grouping new state is
#    InfState           N    T
# 0        I    6.914068  1.5
# 1        S  996.085932  1.5
# before adding dt, current_state is
#    InfState           N    T
# 0        I    6.914068  1.5
# 1        S  996.085932  1.5
# for loop ends
# final current_state is
#    InfState           N     T
# 0        I    6.914068  1.75
# 1        S  996.085932  1.75
# full epi is
#     InfState           N     T
# 0         S  999.000000  0.00
# 1         I    1.000000  0.00
# 2         I    1.124867  0.25
# 3         S  998.875133  0.25
# 4         I    1.265308  0.50
# 5         S  998.734692  0.50
# 6         I    2.547790  0.75
# 7         S  998.452210  0.75
# 8         I    2.865403  1.00
# 9         S  998.134597  1.00
# 10        I    5.470445  1.25
# 11        S  997.529555  1.25
# 12        I    6.150289  1.50
# 13        S  996.849711  1.50
# 14        I    6.914068  1.75
# 15        S  996.085932  1.75
# ----
# initial current_state of each dt is
#    InfState           N     T
# 0        I    6.914068  1.75
# 1        S  996.085932  1.75
# Epi model starts!!!
# current ruleset is
#  [SimpleInfection(stochastic=False, beta=0.5, column='InfState', s_st='S', i_st='I', inf_to='I', freq_dep=True)]
# current rule is
#  stochastic=False beta=0.5 column='InfState' s_st='S' i_st='I' inf_to='I' freq_dep=True
# epi model rule based
# nw_delta is
#    InfState         N     T
# 0        S -0.857931  1.75
# 1        I  0.857931  1.75
# all_deltas is
#    InfState         N     T
# 0        S -0.857931  1.75
# 1        I  0.857931  1.75
# finished current ruleset, moving on
# before concat cur_state and all_deltas, cur_state is
#    InfState           N     T
# 0        I    6.914068  1.75
# 1        S  996.085932  1.75
# before concat cur_state and all_deltas, all_deltas is
#    InfState         N     T
# 0        S -0.857931  1.75
# 1        I  0.857931  1.75
# after concat but before grouping nw_state is
#    InfState           N     T
# 0        I    6.914068  1.75
# 1        S  996.085932  1.75
# 0        S   -0.857931  1.75
# 1        I    0.857931  1.75
# group cols are:  ['InfState']
# ***
# after grouping new state is
#    InfState           N     T
# 0        I    7.771999  1.75
# 1        S  995.228001  1.75
# before adding dt, current_state is
#    InfState           N     T
# 0        I    7.771999  1.75
# 1        S  995.228001  1.75
# for loop ends
# final current_state is
#    InfState           N    T
# 0        I    7.771999  2.0
# 1        S  995.228001  2.0
# full epi is
#     InfState           N     T
# 0         S  999.000000  0.00
# 1         I    1.000000  0.00
# 2         I    1.124867  0.25
# 3         S  998.875133  0.25
# 4         I    1.265308  0.50
# 5         S  998.734692  0.50
# 6         I    2.547790  0.75
# 7         S  998.452210  0.75
# 8         I    2.865403  1.00
# 9         S  998.134597  1.00
# 10        I    5.470445  1.25
# 11        S  997.529555  1.25
# 12        I    6.150289  1.50
# 13        S  996.849711  1.50
# 14        I    6.914068  1.75
# 15        S  996.085932  1.75
# 16        I    7.771999  2.00
# 17        S  995.228001  2.00
# ----
# initial current_state of each dt is
#    InfState           N    T
# 0        I    7.771999  2.0
# 1        S  995.228001  2.0
# Epi model starts!!!
# current ruleset is
#  [SimpleInfection(stochastic=False, beta=0.5, column='InfState', s_st='S', i_st='I', inf_to='I', freq_dep=True)]
# current rule is
#  stochastic=False beta=0.5 column='InfState' s_st='S' i_st='I' inf_to='I' freq_dep=True
# epi model rule based
# nw_delta is
#    InfState         N    T
# 0        S -0.963505  2.0
# 1        I  0.963505  2.0
# all_deltas is
#    InfState         N    T
# 0        S -0.963505  2.0
# 1        I  0.963505  2.0
# finished current ruleset, moving on
# before concat cur_state and all_deltas, cur_state is
#    InfState           N    T
# 0        I    7.771999  2.0
# 1        S  995.228001  2.0
# before concat cur_state and all_deltas, all_deltas is
#    InfState         N    T
# 0        S -0.963505  2.0
# 1        I  0.963505  2.0
# after concat but before grouping nw_state is
#    InfState           N    T
# 0        I    7.771999  2.0
# 1        S  995.228001  2.0
# 0        S   -0.963505  2.0
# 1        I    0.963505  2.0
# group cols are:  ['InfState']
# ***
# after grouping new state is
#    InfState           N    T
# 0        I    8.735505  2.0
# 1        S  994.264495  2.0
# before adding dt, current_state is
#    InfState           N    T
# 0        I    8.735505  2.0
# 1        S  994.264495  2.0
# for loop ends
# final current_state is
#    InfState           N     T
# 0        I    8.735505  2.25
# 1        S  994.264495  2.25
# full epi is
#     InfState           N     T
# 0         S  999.000000  0.00
# 1         I    1.000000  0.00
# 2         I    1.124867  0.25
# 3         S  998.875133  0.25
# 4         I    1.265308  0.50
# 5         S  998.734692  0.50
# 6         I    2.547790  0.75
# 7         S  998.452210  0.75
# 8         I    2.865403  1.00
# 9         S  998.134597  1.00
# 10        I    5.470445  1.25
# 11        S  997.529555  1.25
# 12        I    6.150289  1.50
# 13        S  996.849711  1.50
# 14        I    6.914068  1.75
# 15        S  996.085932  1.75
# 16        I    7.771999  2.00
# 17        S  995.228001  2.00
# 18        I    8.735505  2.25
# 19        S  994.264495  2.25
# ----
# initial current_state of each dt is
#    InfState           N     T
# 0        I    8.735505  2.25
# 1        S  994.264495  2.25
# Epi model starts!!!
# current ruleset is
#  [SimpleInfection(stochastic=False, beta=0.5, column='InfState', s_st='S', i_st='I', inf_to='I', freq_dep=True)]
# current rule is
#  stochastic=False beta=0.5 column='InfState' s_st='S' i_st='I' inf_to='I' freq_dep=True
# epi model rule based
# nw_delta is
#    InfState         N     T
# 0        S -1.081839  2.25
# 1        I  1.081839  2.25
# all_deltas is
#    InfState         N     T
# 0        S -1.081839  2.25
# 1        I  1.081839  2.25
# finished current ruleset, moving on
# before concat cur_state and all_deltas, cur_state is
#    InfState           N     T
# 0        I    8.735505  2.25
# 1        S  994.264495  2.25
# before concat cur_state and all_deltas, all_deltas is
#    InfState         N     T
# 0        S -1.081839  2.25
# 1        I  1.081839  2.25
# after concat but before grouping nw_state is
#    InfState           N     T
# 0        I    8.735505  2.25
# 1        S  994.264495  2.25
# 0        S   -1.081839  2.25
# 1        I    1.081839  2.25
# group cols are:  ['InfState']
# ***
# after grouping new state is
#    InfState           N     T
# 0        I    9.817344  2.25
# 1        S  993.182656  2.25
# before adding dt, current_state is
#    InfState           N     T
# 0        I    9.817344  2.25
# 1        S  993.182656  2.25
# for loop ends
# final current_state is
#    InfState           N    T
# 0        I    9.817344  2.5
# 1        S  993.182656  2.5
# full epi is
#     InfState           N     T
# 0         S  999.000000  0.00
# 1         I    1.000000  0.00
# 2         I    1.124867  0.25
# 3         S  998.875133  0.25
# 4         I    1.265308  0.50
# 5         S  998.734692  0.50
# 6         I    2.547790  0.75
# 7         S  998.452210  0.75
# 8         I    2.865403  1.00
# 9         S  998.134597  1.00
# 10        I    5.470445  1.25
# 11        S  997.529555  1.25
# 12        I    6.150289  1.50
# 13        S  996.849711  1.50
# 14        I    6.914068  1.75
# 15        S  996.085932  1.75
# 16        I    7.771999  2.00
# 17        S  995.228001  2.00
# 18        I    8.735505  2.25
# 19        S  994.264495  2.25
# 20        I    9.817344  2.50
# 21        S  993.182656  2.50
# ----
# initial current_state of each dt is
#    InfState           N    T
# 0        I    9.817344  2.5
# 1        S  993.182656  2.5
# Epi model starts!!!
# current ruleset is
#  [SimpleInfection(stochastic=False, beta=0.5, column='InfState', s_st='S', i_st='I', inf_to='I', freq_dep=True)]
# current rule is
#  stochastic=False beta=0.5 column='InfState' s_st='S' i_st='I' inf_to='I' freq_dep=True
# epi model rule based
# nw_delta is
#    InfState         N    T
# 0        S -1.214413  2.5
# 1        I  1.214413  2.5
# all_deltas is
#    InfState         N    T
# 0        S -1.214413  2.5
# 1        I  1.214413  2.5
# finished current ruleset, moving on
# before concat cur_state and all_deltas, cur_state is
#    InfState           N    T
# 0        I    9.817344  2.5
# 1        S  993.182656  2.5
# before concat cur_state and all_deltas, all_deltas is
#    InfState         N    T
# 0        S -1.214413  2.5
# 1        I  1.214413  2.5
# after concat but before grouping nw_state is
#    InfState           N    T
# 0        I    9.817344  2.5
# 1        S  993.182656  2.5
# 0        S   -1.214413  2.5
# 1        I    1.214413  2.5
# group cols are:  ['InfState']
# ***
# after grouping new state is
#    InfState           N    T
# 0        I   11.031757  2.5
# 1        S  991.968243  2.5
# before adding dt, current_state is
#    InfState           N    T
# 0        I   11.031757  2.5
# 1        S  991.968243  2.5
# for loop ends
# final current_state is
#    InfState           N     T
# 0        I   11.031757  2.75
# 1        S  991.968243  2.75
# full epi is
#     InfState           N     T
# 0         S  999.000000  0.00
# 1         I    1.000000  0.00
# 2         I    1.124867  0.25
# 3         S  998.875133  0.25
# 4         I    1.265308  0.50
# 5         S  998.734692  0.50
# 6         I    2.547790  0.75
# 7         S  998.452210  0.75
# 8         I    2.865403  1.00
# 9         S  998.134597  1.00
# 10        I    5.470445  1.25
# 11        S  997.529555  1.25
# 12        I    6.150289  1.50
# 13        S  996.849711  1.50
# 14        I    6.914068  1.75
# 15        S  996.085932  1.75
# 16        I    7.771999  2.00
# 17        S  995.228001  2.00
# 18        I    8.735505  2.25
# 19        S  994.264495  2.25
# 20        I    9.817344  2.50
# 21        S  993.182656  2.50
# 22        I   11.031757  2.75
# 23        S  991.968243  2.75
# ----
# initial current_state of each dt is
#    InfState           N     T
# 0        I   11.031757  2.75
# 1        S  991.968243  2.75
# Epi model starts!!!
# current ruleset is
#  [SimpleInfection(stochastic=False, beta=0.5, column='InfState', s_st='S', i_st='I', inf_to='I', freq_dep=True)]
# current rule is
#  stochastic=False beta=0.5 column='InfState' s_st='S' i_st='I' inf_to='I' freq_dep=True
# epi model rule based
# nw_delta is
#    InfState         N     T
# 0        S -1.362866  2.75
# 1        I  1.362866  2.75
# all_deltas is
#    InfState         N     T
# 0        S -1.362866  2.75
# 1        I  1.362866  2.75
# finished current ruleset, moving on
# before concat cur_state and all_deltas, cur_state is
#    InfState           N     T
# 0        I   11.031757  2.75
# 1        S  991.968243  2.75
# before concat cur_state and all_deltas, all_deltas is
#    InfState         N     T
# 0        S -1.362866  2.75
# 1        I  1.362866  2.75
# after concat but before grouping nw_state is
#    InfState           N     T
# 0        I   11.031757  2.75
# 1        S  991.968243  2.75
# 0        S   -1.362866  2.75
# 1        I    1.362866  2.75
# group cols are:  ['InfState']
# ***
# after grouping new state is
#    InfState           N     T
# 0        I   12.394623  2.75
# 1        S  990.605377  2.75
# before adding dt, current_state is
#    InfState           N     T
# 0        I   12.394623  2.75
# 1        S  990.605377  2.75
# for loop ends
# final current_state is
#    InfState           N    T
# 0        I   12.394623  3.0
# 1        S  990.605377  3.0
# full epi is
#     InfState           N     T
# 0         S  999.000000  0.00
# 1         I    1.000000  0.00
# 2         I    1.124867  0.25
# 3         S  998.875133  0.25
# 4         I    1.265308  0.50
# 5         S  998.734692  0.50
# 6         I    2.547790  0.75
# 7         S  998.452210  0.75
# 8         I    2.865403  1.00
# 9         S  998.134597  1.00
# 10        I    5.470445  1.25
# 11        S  997.529555  1.25
# 12        I    6.150289  1.50
# 13        S  996.849711  1.50
# 14        I    6.914068  1.75
# 15        S  996.085932  1.75
# 16        I    7.771999  2.00
# 17        S  995.228001  2.00
# 18        I    8.735505  2.25
# 19        S  994.264495  2.25
# 20        I    9.817344  2.50
# 21        S  993.182656  2.50
# 22        I   11.031757  2.75
# 23        S  991.968243  2.75
# 24        I   12.394623  3.00
# 25        S  990.605377  3.00
# ----
# initial current_state of each dt is
#    InfState           N    T
# 0        I   12.394623  3.0
# 1        S  990.605377  3.0
# Epi model starts!!!
# current ruleset is
#  [SimpleInfection(stochastic=False, beta=0.5, column='InfState', s_st='S', i_st='I', inf_to='I', freq_dep=True)]
# current rule is
#  stochastic=False beta=0.5 column='InfState' s_st='S' i_st='I' inf_to='I' freq_dep=True
# epi model rule based
# nw_delta is
#    InfState         N    T
# 0        S -1.529001  3.0
# 1        I  1.529001  3.0
# all_deltas is
#    InfState         N    T
# 0        S -1.529001  3.0
# 1        I  1.529001  3.0
# finished current ruleset, moving on
# before concat cur_state and all_deltas, cur_state is
#    InfState           N    T
# 0        I   12.394623  3.0
# 1        S  990.605377  3.0
# before concat cur_state and all_deltas, all_deltas is
#    InfState         N    T
# 0        S -1.529001  3.0
# 1        I  1.529001  3.0
# after concat but before grouping nw_state is
#    InfState           N    T
# 0        I   12.394623  3.0
# 1        S  990.605377  3.0
# 0        S   -1.529001  3.0
# 1        I    1.529001  3.0
# group cols are:  ['InfState']
# ***
# after grouping new state is
#    InfState           N    T
# 0        I   13.923623  3.0
# 1        S  989.076377  3.0
# before adding dt, current_state is
#    InfState           N    T
# 0        I   13.923623  3.0
# 1        S  989.076377  3.0
# for loop ends
# final current_state is
#    InfState           N     T
# 0        I   13.923623  3.25
# 1        S  989.076377  3.25
# full epi is
#     InfState           N     T
# 0         S  999.000000  0.00
# 1         I    1.000000  0.00
# 2         I    1.124867  0.25
# 3         S  998.875133  0.25
# 4         I    1.265308  0.50
# 5         S  998.734692  0.50
# 6         I    2.547790  0.75
# 7         S  998.452210  0.75
# 8         I    2.865403  1.00
# 9         S  998.134597  1.00
# 10        I    5.470445  1.25
# 11        S  997.529555  1.25
# 12        I    6.150289  1.50
# 13        S  996.849711  1.50
# 14        I    6.914068  1.75
# 15        S  996.085932  1.75
# 16        I    7.771999  2.00
# 17        S  995.228001  2.00
# 18        I    8.735505  2.25
# 19        S  994.264495  2.25
# 20        I    9.817344  2.50
# 21        S  993.182656  2.50
# 22        I   11.031757  2.75
# 23        S  991.968243  2.75
# 24        I   12.394623  3.00
# 25        S  990.605377  3.00
# 26        I   13.923623  3.25
# 27        S  989.076377  3.25
# ----
# initial current_state of each dt is
#    InfState           N     T
# 0        I   13.923623  3.25
# 1        S  989.076377  3.25
# Epi model starts!!!
# current ruleset is
#  [SimpleInfection(stochastic=False, beta=0.5, column='InfState', s_st='S', i_st='I', inf_to='I', freq_dep=True)]
# current rule is
#  stochastic=False beta=0.5 column='InfState' s_st='S' i_st='I' inf_to='I' freq_dep=True
# epi model rule based
# nw_delta is
#    InfState         N     T
# 0        S -1.714804  3.25
# 1        I  1.714804  3.25
# all_deltas is
#    InfState         N     T
# 0        S -1.714804  3.25
# 1        I  1.714804  3.25
# finished current ruleset, moving on
# before concat cur_state and all_deltas, cur_state is
#    InfState           N     T
# 0        I   13.923623  3.25
# 1        S  989.076377  3.25
# before concat cur_state and all_deltas, all_deltas is
#    InfState         N     T
# 0        S -1.714804  3.25
# 1        I  1.714804  3.25
# after concat but before grouping nw_state is
#    InfState           N     T
# 0        I   13.923623  3.25
# 1        S  989.076377  3.25
# 0        S   -1.714804  3.25
# 1        I    1.714804  3.25
# group cols are:  ['InfState']
# ***
# after grouping new state is
#    InfState           N     T
# 0        I   15.638427  3.25
# 1        S  987.361573  3.25
# before adding dt, current_state is
#    InfState           N     T
# 0        I   15.638427  3.25
# 1        S  987.361573  3.25
# for loop ends
# final current_state is
#    InfState           N    T
# 0        I   15.638427  3.5
# 1        S  987.361573  3.5
# full epi is
#     InfState           N     T
# 0         S  999.000000  0.00
# 1         I    1.000000  0.00
# 2         I    1.124867  0.25
# 3         S  998.875133  0.25
# 4         I    1.265308  0.50
# 5         S  998.734692  0.50
# 6         I    2.547790  0.75
# 7         S  998.452210  0.75
# 8         I    2.865403  1.00
# 9         S  998.134597  1.00
# 10        I    5.470445  1.25
# 11        S  997.529555  1.25
# 12        I    6.150289  1.50
# 13        S  996.849711  1.50
# 14        I    6.914068  1.75
# 15        S  996.085932  1.75
# 16        I    7.771999  2.00
# 17        S  995.228001  2.00
# 18        I    8.735505  2.25
# 19        S  994.264495  2.25
# 20        I    9.817344  2.50
# 21        S  993.182656  2.50
# 22        I   11.031757  2.75
# 23        S  991.968243  2.75
# 24        I   12.394623  3.00
# 25        S  990.605377  3.00
# 26        I   13.923623  3.25
# 27        S  989.076377  3.25
# 28        I   15.638427  3.50
# 29        S  987.361573  3.50
# ----
# initial current_state of each dt is
#    InfState           N    T
# 0        I   15.638427  3.5
# 1        S  987.361573  3.5
# Epi model starts!!!
# current ruleset is
#  [SimpleInfection(stochastic=False, beta=0.5, column='InfState', s_st='S', i_st='I', inf_to='I', freq_dep=True)]
# current rule is
#  stochastic=False beta=0.5 column='InfState' s_st='S' i_st='I' inf_to='I' freq_dep=True
# epi model rule based
# nw_delta is
#    InfState         N    T
# 0        S -1.922451  3.5
# 1        I  1.922451  3.5
# all_deltas is
#    InfState         N    T
# 0        S -1.922451  3.5
# 1        I  1.922451  3.5
# finished current ruleset, moving on
# before concat cur_state and all_deltas, cur_state is
#    InfState           N    T
# 0        I   15.638427  3.5
# 1        S  987.361573  3.5
# before concat cur_state and all_deltas, all_deltas is
#    InfState         N    T
# 0        S -1.922451  3.5
# 1        I  1.922451  3.5
# after concat but before grouping nw_state is
#    InfState           N    T
# 0        I   15.638427  3.5
# 1        S  987.361573  3.5
# 0        S   -1.922451  3.5
# 1        I    1.922451  3.5
# group cols are:  ['InfState']
# ***
# after grouping new state is
#    InfState           N    T
# 0        I   17.560878  3.5
# 1        S  985.439122  3.5
# before adding dt, current_state is
#    InfState           N    T
# 0        I   17.560878  3.5
# 1        S  985.439122  3.5
# for loop ends
# final current_state is
#    InfState           N     T
# 0        I   17.560878  3.75
# 1        S  985.439122  3.75
# full epi is
#     InfState           N     T
# 0         S  999.000000  0.00
# 1         I    1.000000  0.00
# 2         I    1.124867  0.25
# 3         S  998.875133  0.25
# 4         I    1.265308  0.50
# 5         S  998.734692  0.50
# 6         I    2.547790  0.75
# 7         S  998.452210  0.75
# 8         I    2.865403  1.00
# 9         S  998.134597  1.00
# 10        I    5.470445  1.25
# 11        S  997.529555  1.25
# 12        I    6.150289  1.50
# 13        S  996.849711  1.50
# 14        I    6.914068  1.75
# 15        S  996.085932  1.75
# 16        I    7.771999  2.00
# 17        S  995.228001  2.00
# 18        I    8.735505  2.25
# 19        S  994.264495  2.25
# 20        I    9.817344  2.50
# 21        S  993.182656  2.50
# 22        I   11.031757  2.75
# 23        S  991.968243  2.75
# 24        I   12.394623  3.00
# 25        S  990.605377  3.00
# 26        I   13.923623  3.25
# 27        S  989.076377  3.25
# 28        I   15.638427  3.50
# 29        S  987.361573  3.50
# 30        I   17.560878  3.75
# 31        S  985.439122  3.75
# ----
# initial current_state of each dt is
#    InfState           N     T
# 0        I   17.560878  3.75
# 1        S  985.439122  3.75
# Epi model starts!!!
# current ruleset is
#  [SimpleInfection(stochastic=False, beta=0.5, column='InfState', s_st='S', i_st='I', inf_to='I', freq_dep=True)]
# current rule is
#  stochastic=False beta=0.5 column='InfState' s_st='S' i_st='I' inf_to='I' freq_dep=True
# epi model rule based
# nw_delta is
#    InfState         N     T
# 0        S -2.154319  3.75
# 1        I  2.154319  3.75
# all_deltas is
#    InfState         N     T
# 0        S -2.154319  3.75
# 1        I  2.154319  3.75
# finished current ruleset, moving on
# before concat cur_state and all_deltas, cur_state is
#    InfState           N     T
# 0        I   17.560878  3.75
# 1        S  985.439122  3.75
# before concat cur_state and all_deltas, all_deltas is
#    InfState         N     T
# 0        S -2.154319  3.75
# 1        I  2.154319  3.75
# after concat but before grouping nw_state is
#    InfState           N     T
# 0        I   17.560878  3.75
# 1        S  985.439122  3.75
# 0        S   -2.154319  3.75
# 1        I    2.154319  3.75
# group cols are:  ['InfState']
# ***
# after grouping new state is
#    InfState           N     T
# 0        I   19.715197  3.75
# 1        S  983.284803  3.75
# before adding dt, current_state is
#    InfState           N     T
# 0        I   19.715197  3.75
# 1        S  983.284803  3.75
# for loop ends
# final current_state is
#    InfState           N    T
# 0        I   19.715197  4.0
# 1        S  983.284803  4.0
# full epi is
#     InfState           N     T
# 0         S  999.000000  0.00
# 1         I    1.000000  0.00
# 2         I    1.124867  0.25
# 3         S  998.875133  0.25
# 4         I    1.265308  0.50
# 5         S  998.734692  0.50
# 6         I    2.547790  0.75
# 7         S  998.452210  0.75
# 8         I    2.865403  1.00
# 9         S  998.134597  1.00
# 10        I    5.470445  1.25
# 11        S  997.529555  1.25
# 12        I    6.150289  1.50
# 13        S  996.849711  1.50
# 14        I    6.914068  1.75
# 15        S  996.085932  1.75
# 16        I    7.771999  2.00
# 17        S  995.228001  2.00
# 18        I    8.735505  2.25
# 19        S  994.264495  2.25
# 20        I    9.817344  2.50
# 21        S  993.182656  2.50
# 22        I   11.031757  2.75
# 23        S  991.968243  2.75
# 24        I   12.394623  3.00
# 25        S  990.605377  3.00
# 26        I   13.923623  3.25
# 27        S  989.076377  3.25
# 28        I   15.638427  3.50
# 29        S  987.361573  3.50
# 30        I   17.560878  3.75
# 31        S  985.439122  3.75
# 32        I   19.715197  4.00
# 33        S  983.284803  4.00
# ----
# initial current_state of each dt is
#    InfState           N    T
# 0        I   19.715197  4.0
# 1        S  983.284803  4.0
# Epi model starts!!!
# current ruleset is
#  [SimpleInfection(stochastic=False, beta=0.5, column='InfState', s_st='S', i_st='I', inf_to='I', freq_dep=True)]
# current rule is
#  stochastic=False beta=0.5 column='InfState' s_st='S' i_st='I' inf_to='I' freq_dep=True
# epi model rule based
# nw_delta is
#    InfState         N    T
# 0        S -2.412993  4.0
# 1        I  2.412993  4.0
# all_deltas is
#    InfState         N    T
# 0        S -2.412993  4.0
# 1        I  2.412993  4.0
# finished current ruleset, moving on
# before concat cur_state and all_deltas, cur_state is
#    InfState           N    T
# 0        I   19.715197  4.0
# 1        S  983.284803  4.0
# before concat cur_state and all_deltas, all_deltas is
#    InfState         N    T
# 0        S -2.412993  4.0
# 1        I  2.412993  4.0
# after concat but before grouping nw_state is
#    InfState           N    T
# 0        I   19.715197  4.0
# 1        S  983.284803  4.0
# 0        S   -2.412993  4.0
# 1        I    2.412993  4.0
# group cols are:  ['InfState']
# ***
# after grouping new state is
#    InfState          N    T
# 0        I   22.12819  4.0
# 1        S  980.87181  4.0
# before adding dt, current_state is
#    InfState          N    T
# 0        I   22.12819  4.0
# 1        S  980.87181  4.0
# for loop ends
# final current_state is
#    InfState          N     T
# 0        I   22.12819  4.25
# 1        S  980.87181  4.25
# full epi is
#     InfState           N     T
# 0         S  999.000000  0.00
# 1         I    1.000000  0.00
# 2         I    1.124867  0.25
# 3         S  998.875133  0.25
# 4         I    1.265308  0.50
# 5         S  998.734692  0.50
# 6         I    2.547790  0.75
# 7         S  998.452210  0.75
# 8         I    2.865403  1.00
# 9         S  998.134597  1.00
# 10        I    5.470445  1.25
# 11        S  997.529555  1.25
# 12        I    6.150289  1.50
# 13        S  996.849711  1.50
# 14        I    6.914068  1.75
# 15        S  996.085932  1.75
# 16        I    7.771999  2.00
# 17        S  995.228001  2.00
# 18        I    8.735505  2.25
# 19        S  994.264495  2.25
# 20        I    9.817344  2.50
# 21        S  993.182656  2.50
# 22        I   11.031757  2.75
# 23        S  991.968243  2.75
# 24        I   12.394623  3.00
# 25        S  990.605377  3.00
# 26        I   13.923623  3.25
# 27        S  989.076377  3.25
# 28        I   15.638427  3.50
# 29        S  987.361573  3.50
# 30        I   17.560878  3.75
# 31        S  985.439122  3.75
# 32        I   19.715197  4.00
# 33        S  983.284803  4.00
# 34        I   22.128190  4.25
# 35        S  980.871810  4.25
# ----
# initial current_state of each dt is
#    InfState          N     T
# 0        I   22.12819  4.25
# 1        S  980.87181  4.25
# Epi model starts!!!
# current ruleset is
#  [SimpleInfection(stochastic=False, beta=0.5, column='InfState', s_st='S', i_st='I', inf_to='I', freq_dep=True)]
# current rule is
#  stochastic=False beta=0.5 column='InfState' s_st='S' i_st='I' inf_to='I' freq_dep=True
# epi model rule based
# nw_delta is
#    InfState         N     T
# 0        S -2.701273  4.25
# 1        I  2.701273  4.25
# all_deltas is
#    InfState         N     T
# 0        S -2.701273  4.25
# 1        I  2.701273  4.25
# finished current ruleset, moving on
# before concat cur_state and all_deltas, cur_state is
#    InfState          N     T
# 0        I   22.12819  4.25
# 1        S  980.87181  4.25
# before concat cur_state and all_deltas, all_deltas is
#    InfState         N     T
# 0        S -2.701273  4.25
# 1        I  2.701273  4.25
# after concat but before grouping nw_state is
#    InfState           N     T
# 0        I   22.128190  4.25
# 1        S  980.871810  4.25
# 0        S   -2.701273  4.25
# 1        I    2.701273  4.25
# group cols are:  ['InfState']
# ***
# after grouping new state is
#    InfState           N     T
# 0        I   24.829463  4.25
# 1        S  978.170537  4.25
# before adding dt, current_state is
#    InfState           N     T
# 0        I   24.829463  4.25
# 1        S  978.170537  4.25
# for loop ends
# final current_state is
#    InfState           N    T
# 0        I   24.829463  4.5
# 1        S  978.170537  4.5
# full epi is
#     InfState           N     T
# 0         S  999.000000  0.00
# 1         I    1.000000  0.00
# 2         I    1.124867  0.25
# 3         S  998.875133  0.25
# 4         I    1.265308  0.50
# 5         S  998.734692  0.50
# 6         I    2.547790  0.75
# 7         S  998.452210  0.75
# 8         I    2.865403  1.00
# 9         S  998.134597  1.00
# 10        I    5.470445  1.25
# 11        S  997.529555  1.25
# 12        I    6.150289  1.50
# 13        S  996.849711  1.50
# 14        I    6.914068  1.75
# 15        S  996.085932  1.75
# 16        I    7.771999  2.00
# 17        S  995.228001  2.00
# 18        I    8.735505  2.25
# 19        S  994.264495  2.25
# 20        I    9.817344  2.50
# 21        S  993.182656  2.50
# 22        I   11.031757  2.75
# 23        S  991.968243  2.75
# 24        I   12.394623  3.00
# 25        S  990.605377  3.00
# 26        I   13.923623  3.25
# 27        S  989.076377  3.25
# 28        I   15.638427  3.50
# 29        S  987.361573  3.50
# 30        I   17.560878  3.75
# 31        S  985.439122  3.75
# 32        I   19.715197  4.00
# 33        S  983.284803  4.00
# 34        I   22.128190  4.25
# 35        S  980.871810  4.25
# 36        I   24.829463  4.50
# 37        S  978.170537  4.50
# ----
# initial current_state of each dt is
#    InfState           N    T
# 0        I   24.829463  4.5
# 1        S  978.170537  4.5
# Epi model starts!!!
# current ruleset is
#  [SimpleInfection(stochastic=False, beta=0.5, column='InfState', s_st='S', i_st='I', inf_to='I', freq_dep=True)]
# current rule is
#  stochastic=False beta=0.5 column='InfState' s_st='S' i_st='I' inf_to='I' freq_dep=True
# epi model rule based
# nw_delta is
#    InfState         N    T
# 0        S -3.022172  4.5
# 1        I  3.022172  4.5
# all_deltas is
#    InfState         N    T
# 0        S -3.022172  4.5
# 1        I  3.022172  4.5
# finished current ruleset, moving on
# before concat cur_state and all_deltas, cur_state is
#    InfState           N    T
# 0        I   24.829463  4.5
# 1        S  978.170537  4.5
# before concat cur_state and all_deltas, all_deltas is
#    InfState         N    T
# 0        S -3.022172  4.5
# 1        I  3.022172  4.5
# after concat but before grouping nw_state is
#    InfState           N    T
# 0        I   24.829463  4.5
# 1        S  978.170537  4.5
# 0        S   -3.022172  4.5
# 1        I    3.022172  4.5
# group cols are:  ['InfState']
# ***
# after grouping new state is
#    InfState           N    T
# 0        I   27.851635  4.5
# 1        S  975.148365  4.5
# before adding dt, current_state is
#    InfState           N    T
# 0        I   27.851635  4.5
# 1        S  975.148365  4.5
# for loop ends
# final current_state is
#    InfState           N     T
# 0        I   27.851635  4.75
# 1        S  975.148365  4.75
# full epi is
#     InfState           N     T
# 0         S  999.000000  0.00
# 1         I    1.000000  0.00
# 2         I    1.124867  0.25
# 3         S  998.875133  0.25
# 4         I    1.265308  0.50
# 5         S  998.734692  0.50
# 6         I    2.547790  0.75
# 7         S  998.452210  0.75
# 8         I    2.865403  1.00
# 9         S  998.134597  1.00
# 10        I    5.470445  1.25
# 11        S  997.529555  1.25
# 12        I    6.150289  1.50
# 13        S  996.849711  1.50
# 14        I    6.914068  1.75
# 15        S  996.085932  1.75
# 16        I    7.771999  2.00
# 17        S  995.228001  2.00
# 18        I    8.735505  2.25
# 19        S  994.264495  2.25
# 20        I    9.817344  2.50
# 21        S  993.182656  2.50
# 22        I   11.031757  2.75
# 23        S  991.968243  2.75
# 24        I   12.394623  3.00
# 25        S  990.605377  3.00
# 26        I   13.923623  3.25
# 27        S  989.076377  3.25
# 28        I   15.638427  3.50
# 29        S  987.361573  3.50
# 30        I   17.560878  3.75
# 31        S  985.439122  3.75
# 32        I   19.715197  4.00
# 33        S  983.284803  4.00
# 34        I   22.128190  4.25
# 35        S  980.871810  4.25
# 36        I   24.829463  4.50
# 37        S  978.170537  4.50
# 38        I   27.851635  4.75
# 39        S  975.148365  4.75
# ----
# initial current_state of each dt is
#    InfState           N     T
# 0        I   27.851635  4.75
# 1        S  975.148365  4.75
# Epi model starts!!!
# current ruleset is
#  [SimpleInfection(stochastic=False, beta=0.5, column='InfState', s_st='S', i_st='I', inf_to='I', freq_dep=True)]
# current rule is
#  stochastic=False beta=0.5 column='InfState' s_st='S' i_st='I' inf_to='I' freq_dep=True
# epi model rule based
# nw_delta is
#    InfState         N     T
# 0        S -3.378913  4.75
# 1        I  3.378913  4.75
# all_deltas is
#    InfState         N     T
# 0        S -3.378913  4.75
# 1        I  3.378913  4.75
# finished current ruleset, moving on
# before concat cur_state and all_deltas, cur_state is
#    InfState           N     T
# 0        I   27.851635  4.75
# 1        S  975.148365  4.75
# before concat cur_state and all_deltas, all_deltas is
#    InfState         N     T
# 0        S -3.378913  4.75
# 1        I  3.378913  4.75
# after concat but before grouping nw_state is
#    InfState           N     T
# 0        I   27.851635  4.75
# 1        S  975.148365  4.75
# 0        S   -3.378913  4.75
# 1        I    3.378913  4.75
# group cols are:  ['InfState']
# ***
# after grouping new state is
#    InfState           N     T
# 0        I   31.230548  4.75
# 1        S  971.769452  4.75
# before adding dt, current_state is
#    InfState           N     T
# 0        I   31.230548  4.75
# 1        S  971.769452  4.75
# for loop ends
# final current_state is
#    InfState           N    T
# 0        I   31.230548  5.0
# 1        S  971.769452  5.0
# full epi is
#     InfState           N     T
# 0         S  999.000000  0.00
# 1         I    1.000000  0.00
# 2         I    1.124867  0.25
# 3         S  998.875133  0.25
# 4         I    1.265308  0.50
# 5         S  998.734692  0.50
# 6         I    2.547790  0.75
# 7         S  998.452210  0.75
# 8         I    2.865403  1.00
# 9         S  998.134597  1.00
# 10        I    5.470445  1.25
# 11        S  997.529555  1.25
# 12        I    6.150289  1.50
# 13        S  996.849711  1.50
# 14        I    6.914068  1.75
# 15        S  996.085932  1.75
# 16        I    7.771999  2.00
# 17        S  995.228001  2.00
# 18        I    8.735505  2.25
# 19        S  994.264495  2.25
# 20        I    9.817344  2.50
# 21        S  993.182656  2.50
# 22        I   11.031757  2.75
# 23        S  991.968243  2.75
# 24        I   12.394623  3.00
# 25        S  990.605377  3.00
# 26        I   13.923623  3.25
# 27        S  989.076377  3.25
# 28        I   15.638427  3.50
# 29        S  987.361573  3.50
# 30        I   17.560878  3.75
# 31        S  985.439122  3.75
# 32        I   19.715197  4.00
# 33        S  983.284803  4.00
# 34        I   22.128190  4.25
# 35        S  980.871810  4.25
# 36        I   24.829463  4.50
# 37        S  978.170537  4.50
# 38        I   27.851635  4.75
# 39        S  975.148365  4.75
# 40        I   31.230548  5.00
# 41        S  971.769452  5.00
# ----
#   InfState           N    T
# 0        I   31.230548  5.0
# 1        S  971.769452  5.0
